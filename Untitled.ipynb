# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
model = load_model('patch_detection.h5',compile=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-637150f47ea4> in <module>
# ----> 1 model = load_model('patch_detection.h5',compile=False)
#
# D:\anaconda3\lib\site-packages\keras\engine\saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# D:\anaconda3\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# ...
